# %% [markdown]
# <a href="https://colab.research.google.com/github/riyarvv/End-to-End-Customer-Churn-ML-Pipeline/blob/main/notebooks/09_Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # End-to-End Customer Churn ML Pipeline
#
# ## Notebook 09 – Feature Engineering
#
# ### Objective
#
# Create new features, organize reusable code into Python modules, and prepare the cleaned dataset for machine learning.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(
"/content/drive/MyDrive/ML Projects/End-to-End-Customer-Churn-ML-Pipeline/data/processed/customer_churn_cleaned.csv"
)

# %%
import os

project_path = "/content/drive/MyDrive/ML Projects/End-to-End-Customer-Churn-ML-Pipeline"

src_path = os.path.join(project_path, "src")

os.makedirs(src_path, exist_ok=True)

files = [
    "__init__.py",
    "data_loader.py",
    "preprocessing.py",
    "feature_engineering.py"
]

for file in files:
  file_path = os.path.join(src_path, file)
  if not os.path.exists(file_path):
    open(file_path, "w").close()

print("src folder and files created successfully")
# Out:
# src folder and files created successfully

# %%
import sys

project_path = "/content/drive/MyDrive/ML Projects/End-to-End-Customer-Churn-ML-Pipeline"

if project_path not in sys.path:
  sys.path.append(project_path)

from src.data_loader import load_data

# %%
df = load_data(
    "/content/drive/MyDrive/ML Projects/End-to-End-Customer-Churn-ML-Pipeline/data/processed/customer_churn_cleaned.csv"
)

df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
from src.feature_engineering import create_new_customer_feature

df = create_new_customer_feature(df)

df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# ...

# %%
df["NewCustomer"].value_counts()
# Out:
# NewCustomer
# 0    4857
# 1    2175
# Name: count, dtype: int64

# %%
from src.feature_engineering import create_tenure_group

df = create_tenure_group(df)

df["TenureGroup"].value_counts()
# Out:
# TenureGroup
# 49-72 Months    2239
# 0-12 Months     2175
# 25-48 Months    1594
# 13-24 Months    1024
# Name: count, dtype: int64

# %%
import sys

# Delete the module from Python's internal cache if it exists
if 'src.feature_engineering' in sys.modules:
    del sys.modules['src.feature_engineering']
if 'src' in sys.modules:
    del sys.modules['src']

# Now re-import and check again
import src.feature_engineering as fe
print(dir(fe))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'create_monthlyCharge_classifier', 'create_new_customer_feature', 'create_tenure_group', 'np', 'pd']

# %%
from src.feature_engineering import create_monthlyCharge_classifier

df = create_monthlyCharge_classifier(df)

df["HighMonthlyCharges"].value_counts()
# Out:
# HighMonthlyCharges
# 0    3519
# 1    3513
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   gender              7032 non-null   object
#  1   SeniorCitizen       7032 non-null   int64
#  2   Partner             7032 non-null   object
#  3   Dependents          7032 non-null   object
#  4   tenure              7032 non-null   int64
#  5   PhoneService        7032 non-null   object
#  6   MultipleLines       7032 non-null   object
#  7   InternetService     7032 non-null   object
#  8   OnlineSecurity      7032 non-null   object
#  9   OnlineBackup        7032 non-null   object
#  10  DeviceProtection    7032 non-null   object
#  11  TechSupport         7032 non-null   object
#  12  StreamingTV         7032 non-null   object
#  13  StreamingMovies     7032 non-null   object
#  14  Contract            7032 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn', 'NewCustomer', 'TenureGroup',
#        'HighMonthlyCharges'],
#       dtype='object')

# %%
df.to_csv(
"/content/drive/MyDrive/ML Projects/End-to-End-Customer-Churn-ML-Pipeline/data/processed/customer_churn_feature_engineered.csv",
index=False
)
